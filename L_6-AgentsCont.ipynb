# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 206 packages in 2.26s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# regex      ------------------------------     0 B/774.15 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# greenlet   ------------------------------     0 B/570.18 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.18 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.18 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.18 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.18 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# langchain-core ------------------------------     0 B/427.40 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.18 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# langchain-core ------------------------------     0 B/427.40 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.18 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# jiter      ------------------------------ 62.92 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# yarl       ------------------------------ 47.93 KiB/349.71 KiB
# langsmith  ------------------------------ 14.91 KiB/351.89 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/378.72 KiB
# rpds-py    ------------------------------ 16.00 KiB/380.31 KiB
# langchain-core ------------------------------ 14.88 KiB/427.40 KiB
# pydantic   ------------------------------ 42.61 KiB/433.50 KiB
# watchfiles ------------------------------ 14.91 KiB/444.09 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# cffi       ------------------------------ 62.89 KiB/456.29 KiB
# huggingface-hub ------------------------------ 30.88 KiB/472.88 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 77.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.88 KiB/569.79 KiB
# greenlet   ------------------------------ 30.92 KiB/570.18 KiB
# chromadb   ------------------------------ 16.00 KiB/613.62 KiB
# openai     ------------------------------ 23.64 KiB/631.81 KiB
# pyvis      ------------------------------ 30.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 77.10 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# jiter      ------------------------------ 172.17 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# yarl       ------------------------------ 140.53 KiB/349.71 KiB
# langsmith  ------------------------------ 30.91 KiB/351.89 KiB
# prompt-toolkit ------------------------------ 46.88 KiB/378.72 KiB
# rpds-py    ------------------------------ 173.06 KiB/380.31 KiB
# langchain-core ------------------------------ 30.88 KiB/427.40 KiB
# pydantic   ------------------------------ 58.61 KiB/433.50 KiB
# watchfiles ------------------------------ 14.91 KiB/444.09 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# cffi       ------------------------------ 174.89 KiB/456.29 KiB
# huggingface-hub ------------------------------ 62.78 KiB/472.88 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 141.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.88 KiB/569.79 KiB
# greenlet   ------------------------------ 62.81 KiB/570.18 KiB
# chromadb   ------------------------------ 26.21 KiB/613.62 KiB
# openai     ------------------------------ 39.64 KiB/631.81 KiB
# pyvis      ------------------------------ 174.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 46.88 KiB/745.07 KiB
# regex      ------------------------------ 144.33 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/199)
# jiter      ------------------------------ 236.17 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# yarl       ------------------------------ 188.53 KiB/349.71 KiB
# langsmith  ------------------------------ 46.91 KiB/351.89 KiB
# prompt-toolkit ------------------------------ 62.77 KiB/378.72 KiB
# rpds-py    ------------------------------ 223.31 KiB/380.31 KiB
# langchain-core ------------------------------ 46.88 KiB/427.40 KiB
# pydantic   ------------------------------ 124.77 KiB/433.50 KiB
# watchfiles ------------------------------ 222.91 KiB/444.09 KiB
# httptools  ------------------------------ 206.91 KiB/449.01 KiB
# cffi       ------------------------------ 238.89 KiB/456.29 KiB
# huggingface-hub ------------------------------ 174.78 KiB/472.88 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 189.71 KiB/523.63 KiB
# crewai-tools ------------------------------ 30.88 KiB/569.79 KiB
# greenlet   ------------------------------ 207.27 KiB/570.18 KiB
# chromadb   ------------------------------ 58.21 KiB/613.62 KiB
# openai     ------------------------------ 55.53 KiB/631.81 KiB
# pyvis      ------------------------------ 238.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 205.54 KiB/745.07 KiB
# regex      ------------------------------ 205.10 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# jiter      ------------------------------ 314.64 KiB/337.45 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# yarl       ------------------------------ 268.53 KiB/349.71 KiB
# langsmith  ------------------------------ 286.23 KiB/351.89 KiB
# prompt-toolkit ------------------------------ 93.00 KiB/378.72 KiB
# rpds-py    ------------------------------ 303.31 KiB/380.31 KiB
# langchain-core ------------------------------ 62.88 KiB/427.40 KiB
# pydantic   ------------------------------ 188.88 KiB/433.50 KiB
# watchfiles ------------------------------ 302.91 KiB/444.09 KiB
# httptools  ------------------------------ 302.91 KiB/449.01 KiB
# cffi       ------------------------------ 334.89 KiB/456.29 KiB
# huggingface-hub ------------------------------ 254.06 KiB/472.88 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 284.66 KiB/523.63 KiB
# crewai-tools ------------------------------ 30.88 KiB/569.79 KiB
# greenlet   ------------------------------ 297.25 KiB/570.18 KiB
# chromadb   ------------------------------ 90.21 KiB/613.62 KiB
# openai     ------------------------------ 71.53 KiB/631.81 KiB
# pyvis      ------------------------------ 318.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 301.32 KiB/745.07 KiB
# regex      ------------------------------ 285.10 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# tzdata     ------------------------------ 75.72 KiB/339.69 KiB
# yarl       ------------------------------ 332.53 KiB/349.71 KiB
# langsmith  ------------------------------ 334.23 KiB/351.89 KiB
# prompt-toolkit ------------------------------ 108.89 KiB/378.72 KiB
# rpds-py    ------------------------------ 351.31 KiB/380.31 KiB
# langchain-core ------------------------------ 77.57 KiB/427.40 KiB
# pydantic   ------------------------------ 236.77 KiB/433.50 KiB
# watchfiles ------------------------------ 350.91 KiB/444.09 KiB
# httptools  ------------------------------ 366.91 KiB/449.01 KiB
# cffi       ------------------------------ 382.89 KiB/456.29 KiB
# huggingface-hub ------------------------------ 320.56 KiB/472.88 KiB
# pytz       ------------------------------ 62.88 KiB/496.10 KiB
# mpmath     ------------------------------ 365.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 46.88 KiB/569.79 KiB
# greenlet   ------------------------------ 345.24 KiB/570.18 KiB
# chromadb   ------------------------------ 106.21 KiB/613.62 KiB
# openai     ------------------------------ 78.89 KiB/631.81 KiB
# pyvis      ------------------------------ 382.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 349.54 KiB/745.07 KiB
# regex      ------------------------------ 349.10 KiB/774.15 KiB
# ipython    ------------------------------ 254.89 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# tzdata     ------------------------------ 75.72 KiB/339.69 KiB
# yarl       ------------------------------ 348.53 KiB/349.71 KiB
# langsmith  ------------------------------ 350.23 KiB/351.89 KiB
# prompt-toolkit ------------------------------ 108.89 KiB/378.72 KiB
# rpds-py    ------------------------------ 380.31 KiB/380.31 KiB
# langchain-core ------------------------------ 109.57 KiB/427.40 KiB
# pydantic   ------------------------------ 252.77 KiB/433.50 KiB
# watchfiles ------------------------------ 366.91 KiB/444.09 KiB
# httptools  ------------------------------ 382.91 KiB/449.01 KiB
# cffi       ------------------------------ 392.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 334.06 KiB/472.88 KiB
# pytz       ------------------------------ 109.92 KiB/496.10 KiB
# mpmath     ------------------------------ 382.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 62.88 KiB/569.79 KiB
# greenlet   ------------------------------ 367.47 KiB/570.18 KiB
# chromadb   ------------------------------ 298.21 KiB/613.62 KiB
# openai     ------------------------------ 78.89 KiB/631.81 KiB
# pyvis      ------------------------------ 408.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 365.54 KiB/745.07 KiB
# regex      ------------------------------ 369.06 KiB/774.15 KiB
# ipython    ------------------------------ 270.89 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# qdrant-client ------------------------------ 16.00 KiB/320.01 KiB
# tzdata     ------------------------------ 75.72 KiB/339.69 KiB
# yarl       ------------------------------ 348.53 KiB/349.71 KiB
# langsmith  ------------------------------ 350.23 KiB/351.89 KiB
# prompt-toolkit ------------------------------ 108.89 KiB/378.72 KiB
# langchain-core ------------------------------ 109.57 KiB/427.40 KiB
# pydantic   ------------------------------ 252.77 KiB/433.50 KiB
# watchfiles ------------------------------ 382.91 KiB/444.09 KiB
# httptools  ------------------------------ 392.56 KiB/449.01 KiB
# cffi       ------------------------------ 408.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 334.06 KiB/472.88 KiB
# pytz       ------------------------------ 109.92 KiB/496.10 KiB
# mpmath     ------------------------------ 397.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 62.88 KiB/569.79 KiB
# greenlet   ------------------------------ 383.47 KiB/570.18 KiB
# chromadb   ------------------------------ 314.21 KiB/613.62 KiB
# openai     ------------------------------ 78.89 KiB/631.81 KiB
# pyvis      ------------------------------ 419.45 KiB/738.32 KiB
# pyyaml     ------------------------------ 381.54 KiB/745.07 KiB
# regex      ------------------------------ 385.06 KiB/774.15 KiB
# ipython    ------------------------------ 286.89 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# qdrant-client ------------------------------ 16.00 KiB/320.01 KiB
# tzdata     ------------------------------ 75.72 KiB/339.69 KiB
# langsmith  ------------------------------ 350.23 KiB/351.89 KiB
# prompt-toolkit ------------------------------ 124.89 KiB/378.72 KiB
# langchain-core ------------------------------ 109.57 KiB/427.40 KiB
# pydantic   ------------------------------ 268.77 KiB/433.50 KiB
# watchfiles ------------------------------ 392.56 KiB/444.09 KiB
# httptools  ------------------------------ 408.56 KiB/449.01 KiB
# cffi       ------------------------------ 408.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 334.06 KiB/472.88 KiB
# pytz       ------------------------------ 109.92 KiB/496.10 KiB
# mpmath     ------------------------------ 397.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 62.88 KiB/569.79 KiB
# greenlet   ------------------------------ 383.47 KiB/570.18 KiB
# chromadb   ------------------------------ 314.21 KiB/613.62 KiB
# openai     ------------------------------ 94.89 KiB/631.81 KiB
# pyvis      ------------------------------ 435.45 KiB/738.32 KiB
# pyyaml     ------------------------------ 397.54 KiB/745.07 KiB
# regex      ------------------------------ 385.06 KiB/774.15 KiB
# ipython    ------------------------------ 286.89 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# qdrant-client ------------------------------ 32.00 KiB/320.01 KiB
# tzdata     ------------------------------ 75.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 124.89 KiB/378.72 KiB
# langchain-core ------------------------------ 125.57 KiB/427.40 KiB
# pydantic   ------------------------------ 268.77 KiB/433.50 KiB
# watchfiles ------------------------------ 392.56 KiB/444.09 KiB
# httptools  ------------------------------ 424.56 KiB/449.01 KiB
# cffi       ------------------------------ 408.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 334.06 KiB/472.88 KiB
# pytz       ------------------------------ 109.92 KiB/496.10 KiB
# mpmath     ------------------------------ 413.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 62.88 KiB/569.79 KiB
# greenlet   ------------------------------ 396.16 KiB/570.18 KiB
# chromadb   ------------------------------ 314.21 KiB/613.62 KiB
# openai     ------------------------------ 94.89 KiB/631.81 KiB
# pyvis      ------------------------------ 435.45 KiB/738.32 KiB
# pyyaml     ------------------------------ 413.54 KiB/745.07 KiB
# regex      ------------------------------ 397.10 KiB/774.15 KiB
# ipython    ------------------------------ 286.89 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 398.04 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# crewai     ------------------------------ 8.74 KiB/301.49 KiB
# frozenlist ------------------------------ 13.86 KiB/306.27 KiB
# protobuf   ------------------------------ 32.00 KiB/312.18 KiB
# qdrant-client ------------------------------ 48.00 KiB/320.01 KiB
# tzdata     ------------------------------ 91.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 140.79 KiB/378.72 KiB
# langchain-core ------------------------------ 141.57 KiB/427.40 KiB
# pydantic   ------------------------------ 284.88 KiB/433.50 KiB
# watchfiles ------------------------------ 434.71 KiB/444.09 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# huggingface-hub ------------------------------ 345.40 KiB/472.88 KiB
# pytz       ------------------------------ 109.92 KiB/496.10 KiB
# mpmath     ------------------------------ 429.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 62.88 KiB/569.79 KiB
# greenlet   ------------------------------ 444.16 KiB/570.18 KiB
# chromadb   ------------------------------ 314.21 KiB/613.62 KiB
# openai     ------------------------------ 110.89 KiB/631.81 KiB
# pyvis      ------------------------------ 472.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 434.54 KiB/745.07 KiB
# regex      ------------------------------ 429.28 KiB/774.15 KiB
# ipython    ------------------------------ 350.89 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# crewai     ------------------------------ 24.74 KiB/301.49 KiB
# frozenlist ------------------------------ 29.76 KiB/306.27 KiB
# protobuf   ------------------------------ 48.00 KiB/312.18 KiB
# qdrant-client ------------------------------ 91.39 KiB/320.01 KiB
# tzdata     ------------------------------ 91.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 140.79 KiB/378.72 KiB
# langchain-core ------------------------------ 157.57 KiB/427.40 KiB
# pydantic   ------------------------------ 300.88 KiB/433.50 KiB
# watchfiles ------------------------------ 444.09 KiB/444.09 KiB
# huggingface-hub ------------------------------ 345.40 KiB/472.88 KiB
# pytz       ------------------------------ 109.92 KiB/496.10 KiB
# mpmath     ------------------------------ 477.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 78.88 KiB/569.79 KiB
# greenlet   ------------------------------ 444.16 KiB/570.18 KiB
# chromadb   ------------------------------ 314.21 KiB/613.62 KiB
# openai     ------------------------------ 126.89 KiB/631.81 KiB
# pyvis      ------------------------------ 488.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 461.54 KiB/745.07 KiB
# regex      ------------------------------ 445.28 KiB/774.15 KiB
# ipython    ------------------------------ 350.89 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# crewai     ------------------------------ 24.74 KiB/301.49 KiB
# frozenlist ------------------------------ 29.76 KiB/306.27 KiB
# protobuf   ------------------------------ 48.00 KiB/312.18 KiB
# qdrant-client ------------------------------ 91.39 KiB/320.01 KiB
# tzdata     ------------------------------ 91.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 140.79 KiB/378.72 KiB
# langchain-core ------------------------------ 157.57 KiB/427.40 KiB
# pydantic   ------------------------------ 300.88 KiB/433.50 KiB
# watchfiles ------------------------------ 444.09 KiB/444.09 KiB
# huggingface-hub ------------------------------ 345.40 KiB/472.88 KiB
# pytz       ------------------------------ 109.92 KiB/496.10 KiB
# mpmath     ------------------------------ 477.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 78.88 KiB/569.79 KiB
# greenlet   ------------------------------ 444.16 KiB/570.18 KiB
# chromadb   ------------------------------ 314.21 KiB/613.62 KiB
# openai     ------------------------------ 126.89 KiB/631.81 KiB
# pyvis      ------------------------------ 488.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 461.54 KiB/745.07 KiB
# regex      ------------------------------ 445.28 KiB/774.15 KiB
# ipython    ------------------------------ 350.89 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# pypdf      ------------------------------     0 B/296.26 KiB
# crewai     ------------------------------ 24.74 KiB/301.49 KiB
# frozenlist ------------------------------ 45.76 KiB/306.27 KiB
# protobuf   ------------------------------ 61.80 KiB/312.18 KiB
# qdrant-client ------------------------------ 91.39 KiB/320.01 KiB
# tzdata     ------------------------------ 91.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 140.79 KiB/378.72 KiB
# langchain-core ------------------------------ 157.57 KiB/427.40 KiB
# pydantic   ------------------------------ 300.88 KiB/433.50 KiB
# huggingface-hub ------------------------------ 345.40 KiB/472.88 KiB
# pytz       ------------------------------ 109.92 KiB/496.10 KiB
# mpmath     ------------------------------ 477.81 KiB/523.63 KiB
# crewai-tools ------------------------------ 78.88 KiB/569.79 KiB
# greenlet   ------------------------------ 444.16 KiB/570.18 KiB
# chromadb   ------------------------------ 314.21 KiB/613.62 KiB
# openai     ------------------------------ 126.89 KiB/631.81 KiB
# pyvis      ------------------------------ 488.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 461.54 KiB/745.07 KiB
# regex      ------------------------------ 461.10 KiB/774.15 KiB
# ipython    ------------------------------ 350.89 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# bcrypt     ------------------------------ 59.84 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 32.00 KiB/287.63 KiB
# pypdf      ------------------------------ 64.00 KiB/296.26 KiB
# crewai     ------------------------------ 72.74 KiB/301.49 KiB
# frozenlist ------------------------------ 81.03 KiB/306.27 KiB
# protobuf   ------------------------------ 125.80 KiB/312.18 KiB
# qdrant-client ------------------------------ 144.00 KiB/320.01 KiB
# tzdata     ------------------------------ 91.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 205.00 KiB/378.72 KiB
# langchain-core ------------------------------ 205.57 KiB/427.40 KiB
# pydantic   ------------------------------ 412.88 KiB/433.50 KiB
# huggingface-hub ------------------------------ 393.40 KiB/472.88 KiB
# pytz       ------------------------------ 125.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 126.78 KiB/569.79 KiB
# greenlet   ------------------------------ 476.16 KiB/570.18 KiB
# chromadb   ------------------------------ 400.52 KiB/613.62 KiB
# openai     ------------------------------ 158.89 KiB/631.81 KiB
# pyvis      ------------------------------ 552.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 541.54 KiB/745.07 KiB
# regex      ------------------------------ 524.99 KiB/774.15 KiB
# ipython    ------------------------------ 408.56 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# bcrypt     ------------------------------ 59.84 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 48.00 KiB/287.63 KiB
# pypdf      ------------------------------ 64.00 KiB/296.26 KiB
# crewai     ------------------------------ 72.74 KiB/301.49 KiB
# frozenlist ------------------------------ 97.03 KiB/306.27 KiB
# protobuf   ------------------------------ 141.80 KiB/312.18 KiB
# qdrant-client ------------------------------ 144.00 KiB/320.01 KiB
# tzdata     ------------------------------ 91.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 205.00 KiB/378.72 KiB
# langchain-core ------------------------------ 205.57 KiB/427.40 KiB
# pydantic   ------------------------------ 428.88 KiB/433.50 KiB
# huggingface-hub ------------------------------ 393.40 KiB/472.88 KiB
# pytz       ------------------------------ 125.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 206.88 KiB/569.79 KiB
# greenlet   ------------------------------ 476.16 KiB/570.18 KiB
# chromadb   ------------------------------ 410.21 KiB/613.62 KiB
# openai     ------------------------------ 174.89 KiB/631.81 KiB
# pyvis      ------------------------------ 568.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 541.54 KiB/745.07 KiB
# regex      ------------------------------ 525.10 KiB/774.15 KiB
# ipython    ------------------------------ 424.56 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/199)
# bcrypt     ------------------------------ 63.28 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 48.00 KiB/287.63 KiB
# pypdf      ------------------------------ 80.00 KiB/296.26 KiB
# crewai     ------------------------------ 72.74 KiB/301.49 KiB
# frozenlist ------------------------------ 97.03 KiB/306.27 KiB
# protobuf   ------------------------------ 141.80 KiB/312.18 KiB
# qdrant-client ------------------------------ 144.00 KiB/320.01 KiB
# tzdata     ------------------------------ 91.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 221.00 KiB/378.72 KiB
# langchain-core ------------------------------ 205.57 KiB/427.40 KiB
# huggingface-hub ------------------------------ 414.06 KiB/472.88 KiB
# pytz       ------------------------------ 125.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 350.88 KiB/569.79 KiB
# greenlet   ------------------------------ 476.16 KiB/570.18 KiB
# chromadb   ------------------------------ 410.21 KiB/613.62 KiB
# openai     ------------------------------ 174.89 KiB/631.81 KiB
# pyvis      ------------------------------ 568.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 557.54 KiB/745.07 KiB
# regex      ------------------------------ 525.10 KiB/774.15 KiB
# ipython    ------------------------------ 424.56 KiB/811.60 KiB
# langchain  ------------------------------ 62.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# openpyxl   ------------------------------ 14.88 KiB/245.03 KiB
# cohere     ------------------------------ 46.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 147.65 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 77.48 KiB/287.63 KiB
# pypdf      ------------------------------ 176.00 KiB/296.26 KiB
# crewai     ------------------------------ 104.74 KiB/301.49 KiB
# frozenlist ------------------------------ 192.00 KiB/306.27 KiB
# protobuf   ------------------------------ 221.80 KiB/312.18 KiB
# qdrant-client ------------------------------ 224.00 KiB/320.01 KiB
# tzdata     ------------------------------ 107.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 301.00 KiB/378.72 KiB
# langchain-core ------------------------------ 317.57 KiB/427.40 KiB
# huggingface-hub ------------------------------ 462.06 KiB/472.88 KiB
# pytz       ------------------------------ 141.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 510.88 KiB/569.79 KiB
# greenlet   ------------------------------ 544.17 KiB/570.18 KiB
# chromadb   ------------------------------ 454.93 KiB/613.62 KiB
# openai     ------------------------------ 222.78 KiB/631.81 KiB
# pyvis      ------------------------------ 664.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 653.32 KiB/745.07 KiB
# regex      ------------------------------ 620.88 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# cohere     ------------------------------ 62.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 163.65 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 93.48 KiB/287.63 KiB
# pypdf      ------------------------------ 192.00 KiB/296.26 KiB
# crewai     ------------------------------ 104.74 KiB/301.49 KiB
# frozenlist ------------------------------ 208.00 KiB/306.27 KiB
# protobuf   ------------------------------ 253.80 KiB/312.18 KiB
# qdrant-client ------------------------------ 240.00 KiB/320.01 KiB
# tzdata     ------------------------------ 107.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 333.00 KiB/378.72 KiB
# langchain-core ------------------------------ 333.57 KiB/427.40 KiB
# pytz       ------------------------------ 141.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 510.88 KiB/569.79 KiB
# greenlet   ------------------------------ 560.17 KiB/570.18 KiB
# chromadb   ------------------------------ 470.93 KiB/613.62 KiB
# openai     ------------------------------ 238.78 KiB/631.81 KiB
# pyvis      ------------------------------ 693.01 KiB/738.32 KiB
# pyyaml     ------------------------------ 669.32 KiB/745.07 KiB
# regex      ------------------------------ 642.80 KiB/774.15 KiB
# ipython    ------------------------------ 488.56 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# rich       ------------------------------ 16.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# cohere     ------------------------------ 75.43 KiB/253.44 KiB
# bcrypt     ------------------------------ 186.56 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 109.48 KiB/287.63 KiB
# pypdf      ------------------------------ 224.00 KiB/296.26 KiB
# crewai     ------------------------------ 104.74 KiB/301.49 KiB
# frozenlist ------------------------------ 245.04 KiB/306.27 KiB
# protobuf   ------------------------------ 269.80 KiB/312.18 KiB
# qdrant-client ------------------------------ 256.00 KiB/320.01 KiB
# tzdata     ------------------------------ 107.72 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 349.00 KiB/378.72 KiB
# langchain-core ------------------------------ 365.57 KiB/427.40 KiB
# pytz       ------------------------------ 141.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 526.88 KiB/569.79 KiB
# chromadb   ------------------------------ 470.93 KiB/613.62 KiB
# openai     ------------------------------ 254.78 KiB/631.81 KiB
# pyvis      ------------------------------ 712.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 687.37 KiB/745.07 KiB
# regex      ------------------------------ 669.10 KiB/774.15 KiB
# ipython    ------------------------------ 563.46 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# tomli      ------------------------------     0 B/230.50 KiB
# rich       ------------------------------ 48.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# cohere     ------------------------------ 75.43 KiB/253.44 KiB
# bcrypt     ------------------------------ 207.28 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 125.48 KiB/287.63 KiB
# pypdf      ------------------------------ 240.00 KiB/296.26 KiB
# crewai     ------------------------------ 120.74 KiB/301.49 KiB
# frozenlist ------------------------------ 256.00 KiB/306.27 KiB
# protobuf   ------------------------------ 301.80 KiB/312.18 KiB
# qdrant-client ------------------------------ 300.41 KiB/320.01 KiB
# tzdata     ------------------------------ 107.72 KiB/339.69 KiB
# langchain-core ------------------------------ 381.57 KiB/427.40 KiB
# pytz       ------------------------------ 157.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 526.88 KiB/569.79 KiB
# chromadb   ------------------------------ 485.61 KiB/613.62 KiB
# openai     ------------------------------ 270.78 KiB/631.81 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# pyyaml     ------------------------------ 703.37 KiB/745.07 KiB
# regex      ------------------------------ 696.26 KiB/774.15 KiB
# ipython    ------------------------------ 584.56 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# tomli      ------------------------------     0 B/230.50 KiB
# rich       ------------------------------ 48.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# cohere     ------------------------------ 75.43 KiB/253.44 KiB
# bcrypt     ------------------------------ 218.98 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 125.48 KiB/287.63 KiB
# pypdf      ------------------------------ 240.00 KiB/296.26 KiB
# crewai     ------------------------------ 120.74 KiB/301.49 KiB
# frozenlist ------------------------------ 272.00 KiB/306.27 KiB
# protobuf   ------------------------------ 301.80 KiB/312.18 KiB
# qdrant-client ------------------------------ 300.41 KiB/320.01 KiB
# tzdata     ------------------------------ 107.72 KiB/339.69 KiB
# langchain-core ------------------------------ 381.57 KiB/427.40 KiB
# pytz       ------------------------------ 157.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 526.88 KiB/569.79 KiB
# chromadb   ------------------------------ 485.61 KiB/613.62 KiB
# openai     ------------------------------ 270.78 KiB/631.81 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# pyyaml     ------------------------------ 719.37 KiB/745.07 KiB
# regex      ------------------------------ 696.26 KiB/774.15 KiB
# ipython    ------------------------------ 584.56 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# propcache  ------------------------------     0 B/227.05 KiB
# tomli      ------------------------------ 32.00 KiB/230.50 KiB
# rich       ------------------------------ 48.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# cohere     ------------------------------ 75.43 KiB/253.44 KiB
# bcrypt     ------------------------------ 234.98 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 141.48 KiB/287.63 KiB
# pypdf      ------------------------------ 256.00 KiB/296.26 KiB
# crewai     ------------------------------ 120.74 KiB/301.49 KiB
# frozenlist ------------------------------ 288.00 KiB/306.27 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# qdrant-client ------------------------------ 316.41 KiB/320.01 KiB
# tzdata     ------------------------------ 123.72 KiB/339.69 KiB
# langchain-core ------------------------------ 397.57 KiB/427.40 KiB
# pytz       ------------------------------ 157.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 542.88 KiB/569.79 KiB
# chromadb   ------------------------------ 485.61 KiB/613.62 KiB
# openai     ------------------------------ 270.78 KiB/631.81 KiB
# pyyaml     ------------------------------ 733.54 KiB/745.07 KiB
# regex      ------------------------------ 728.26 KiB/774.15 KiB
# ipython    ------------------------------ 600.56 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# propcache  ------------------------------ 14.88 KiB/227.05 KiB
# tomli      ------------------------------ 32.00 KiB/230.50 KiB
# rich       ------------------------------ 48.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# cohere     ------------------------------ 75.43 KiB/253.44 KiB
# bcrypt     ------------------------------ 250.98 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 141.48 KiB/287.63 KiB
# pypdf      ------------------------------ 256.00 KiB/296.26 KiB
# crewai     ------------------------------ 120.74 KiB/301.49 KiB
# frozenlist ------------------------------ 304.00 KiB/306.27 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# tzdata     ------------------------------ 123.72 KiB/339.69 KiB
# langchain-core ------------------------------ 397.57 KiB/427.40 KiB
# pytz       ------------------------------ 157.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 542.88 KiB/569.79 KiB
# chromadb   ------------------------------ 501.61 KiB/613.62 KiB
# openai     ------------------------------ 270.78 KiB/631.81 KiB
# pyyaml     ------------------------------ 745.07 KiB/745.07 KiB
# regex      ------------------------------ 728.26 KiB/774.15 KiB
# ipython    ------------------------------ 616.56 KiB/811.60 KiB
# langchain  ------------------------------ 126.67 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# propcache  ------------------------------ 14.88 KiB/227.05 KiB
# tomli      ------------------------------ 48.00 KiB/230.50 KiB
# rich       ------------------------------ 61.35 KiB/236.74 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# cohere     ------------------------------ 78.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 250.98 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 141.48 KiB/287.63 KiB
# pypdf      ------------------------------ 256.00 KiB/296.26 KiB
# crewai     ------------------------------ 120.74 KiB/301.49 KiB
# frozenlist ------------------------------ 304.00 KiB/306.27 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# tzdata     ------------------------------ 123.72 KiB/339.69 KiB
# langchain-core ------------------------------ 397.57 KiB/427.40 KiB
# pytz       ------------------------------ 157.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 542.88 KiB/569.79 KiB
# chromadb   ------------------------------ 501.61 KiB/613.62 KiB
# openai     ------------------------------ 270.78 KiB/631.81 KiB
# regex      ------------------------------ 733.10 KiB/774.15 KiB
# ipython    ------------------------------ 616.56 KiB/811.60 KiB
# langchain  ------------------------------ 126.67 KiB/987.31 KiB
# tiktoken   ------------------------------ 734.04 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# multidict  ------------------------------     0 B/218.25 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# alembic    ------------------------------ 14.88 KiB/226.48 KiB
# propcache  ------------------------------ 46.88 KiB/227.05 KiB
# tomli      ------------------------------ 51.55 KiB/230.50 KiB
# rich       ------------------------------ 61.35 KiB/236.74 KiB
# openpyxl   ------------------------------ 62.88 KiB/245.03 KiB
# cohere     ------------------------------ 94.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 271.28 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 141.48 KiB/287.63 KiB
# pypdf      ------------------------------ 288.00 KiB/296.26 KiB
# crewai     ------------------------------ 136.62 KiB/301.49 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# tzdata     ------------------------------ 123.72 KiB/339.69 KiB
# langchain-core ------------------------------ 427.40 KiB/427.40 KiB
# pytz       ------------------------------ 173.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 542.88 KiB/569.79 KiB
# chromadb   ------------------------------ 501.61 KiB/613.62 KiB
# openai     ------------------------------ 286.89 KiB/631.81 KiB
# regex      ------------------------------ 749.10 KiB/774.15 KiB
# ipython    ------------------------------ 632.56 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# multidict  ------------------------------     0 B/218.25 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# alembic    ------------------------------ 14.88 KiB/226.48 KiB
# propcache  ------------------------------ 46.88 KiB/227.05 KiB
# tomli      ------------------------------ 51.55 KiB/230.50 KiB
# rich       ------------------------------ 61.35 KiB/236.74 KiB
# openpyxl   ------------------------------ 62.88 KiB/245.03 KiB
# cohere     ------------------------------ 94.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 271.28 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 141.48 KiB/287.63 KiB
# pypdf      ------------------------------ 288.00 KiB/296.26 KiB
# crewai     ------------------------------ 136.62 KiB/301.49 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# tzdata     ------------------------------ 123.72 KiB/339.69 KiB
# pytz       ------------------------------ 173.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 542.88 KiB/569.79 KiB
# chromadb   ------------------------------ 501.61 KiB/613.62 KiB
# openai     ------------------------------ 286.89 KiB/631.81 KiB
# regex      ------------------------------ 749.10 KiB/774.15 KiB
# ipython    ------------------------------ 632.56 KiB/811.60 KiB
# langchain  ------------------------------ 126.67 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# embedchain ------------------------------     0 B/206.39 KiB
# google-auth ------------------------------     0 B/211.04 KiB
# multidict  ------------------------------ 14.88 KiB/218.25 KiB
# python-dateutil ------------------------------ 16.00 KiB/224.50 KiB
# alembic    ------------------------------ 30.88 KiB/226.48 KiB
# propcache  ------------------------------ 77.52 KiB/227.05 KiB
# tomli      ------------------------------ 80.00 KiB/230.50 KiB
# rich       ------------------------------ 77.35 KiB/236.74 KiB
# openpyxl   ------------------------------ 62.88 KiB/245.03 KiB
# cohere     ------------------------------ 94.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 277.50 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 157.48 KiB/287.63 KiB
# pypdf      ------------------------------ 288.00 KiB/296.26 KiB
# crewai     ------------------------------ 142.65 KiB/301.49 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# tzdata     ------------------------------ 123.72 KiB/339.69 KiB
# pytz       ------------------------------ 173.92 KiB/496.10 KiB
# crewai-tools ------------------------------ 558.67 KiB/569.79 KiB
# chromadb   ------------------------------ 501.61 KiB/613.62 KiB
# openai     ------------------------------ 286.89 KiB/631.81 KiB
# ipython    ------------------------------ 648.56 KiB/811.60 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/199)
# embedchain ------------------------------     0 B/206.39 KiB
# google-auth ------------------------------     0 B/211.04 KiB
# multidict  ------------------------------ 15.26 KiB/218.25 KiB
# python-dateutil ------------------------------ 16.00 KiB/224.50 KiB
# alembic    ------------------------------ 30.88 KiB/226.48 KiB
# propcache  ------------------------------ 77.52 KiB/227.05 KiB
# ...
# lancedb    ------------------------------ 15.67 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 16.00 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠇ Preparing packages... (191/199)
# pyright    ------------------------------ 4.11 MiB/5.31 MiB
# pandas     ------------------------------ 12.31 MiB/12.45 MiB
# onnxruntime ------------------------------ 14.82 MiB/15.63 MiB
# numpy      ------------------------------ 14.46 MiB/15.67 MiB
# uv         ------------------------------ 15.16 MiB/16.59 MiB
# lancedb    ------------------------------ 15.67 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 16.00 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠇ Preparing packages... (191/199)
# pyright    ------------------------------ 4.11 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.82 MiB/15.63 MiB
# numpy      ------------------------------ 15.57 MiB/15.67 MiB
# uv         ------------------------------ 15.16 MiB/16.59 MiB
# lancedb    ------------------------------ 15.67 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 16.00 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠇ Preparing packages... (191/199)
# pyright    ------------------------------ 4.11 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.82 MiB/15.63 MiB
# uv         ------------------------------ 15.16 MiB/16.59 MiB
# lancedb    ------------------------------ 15.67 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 16.00 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠇ Preparing packages... (191/199)
# pyright    ------------------------------ 4.11 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.82 MiB/15.63 MiB
# uv         ------------------------------ 16.05 MiB/16.59 MiB
# lancedb    ------------------------------ 15.67 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 16.59 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠋ Preparing packages... (193/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.82 MiB/15.63 MiB
# uv         ------------------------------ 16.59 MiB/16.59 MiB
# lancedb    ------------------------------ 17.39 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 19.04 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠋ Preparing packages... (193/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.82 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 19.24 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠙ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 19.24 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠙ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 19.33 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠙ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 19.35 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠙ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 19.36 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠙ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 21.07 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠹ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 22.73 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠹ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 22.81 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠹ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 22.83 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠹ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 22.84 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠹ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 22.99 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠸ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 22.99 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠸ Preparing packages... (194/199)
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.93 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.27 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠸ Preparing packages... (194/199)
# pyright    ------------------------------ 4.20 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.98 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.27 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠸ Preparing packages... (194/199)
# pyright    ------------------------------ 4.23 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.13 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.27 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠼ Preparing packages... (194/199)
# pyright    ------------------------------ 4.23 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.27 MiB/15.63 MiB
# lancedb    ------------------------------ 17.70 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.27 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠼ Preparing packages... (194/199)
# pyright    ------------------------------ 4.31 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.27 MiB/15.63 MiB
# lancedb    ------------------------------ 17.77 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.27 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠼ Preparing packages... (194/199)
# pyright    ------------------------------ 4.31 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.27 MiB/15.63 MiB
# lancedb    ------------------------------ 19.05 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.27 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠼ Preparing packages... (194/199)
# pyright    ------------------------------ 4.31 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.29 MiB/15.63 MiB
# lancedb    ------------------------------ 20.21 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.27 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠼ Preparing packages... (194/199)
# pyright    ------------------------------ 4.31 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.30 MiB/15.63 MiB
# lancedb    ------------------------------ 20.21 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.27 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠴ Preparing packages... (194/199)
# pyright    ------------------------------ 4.31 MiB/5.31 MiB
# lancedb    ------------------------------ 20.21 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.27 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠴ Preparing packages... (194/199)
# pyright    ------------------------------ 4.31 MiB/5.31 MiB
# lancedb    ------------------------------ 20.21 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.32 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠴ Preparing packages... (194/199)
# pyright    ------------------------------ 4.31 MiB/5.31 MiB
# lancedb    ------------------------------ 20.21 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 24.33 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠴ Preparing packages... (194/199)
# pyright    ------------------------------ 4.36 MiB/5.31 MiB
# lancedb    ------------------------------ 20.21 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 28.53 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠴ Preparing packages... (194/199)
# pyright    ------------------------------ 4.36 MiB/5.31 MiB
# lancedb    ------------------------------ 23.67 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 30.47 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠦ Preparing packages... (195/199)
# pyright    ------------------------------ 4.36 MiB/5.31 MiB
# lancedb    ------------------------------ 27.25 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 32.60 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠦ Preparing packages... (195/199)
# pyright    ------------------------------ 4.36 MiB/5.31 MiB
# lancedb    ------------------------------ 31.23 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 34.03 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠦ Preparing packages... (195/199)
# pyright    ------------------------------ 4.37 MiB/5.31 MiB
# lancedb    ------------------------------ 32.22 MiB/32.22 MiB
# Building sqlalchemy==2.0.41m 38.26 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠦ Preparing packages... (195/199)
# pyright    ------------------------------ 4.37 MiB/5.31 MiB
# Building sqlalchemy==2.0.41m 38.26 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠦ Preparing packages... (195/199)
# pyright    ------------------------------ 4.58 MiB/5.31 MiB
# Building sqlalchemy==2.0.41m 39.49 MiB/40.34 MiB
#    Built pypika==0.48.9
# ⠦ Preparing packages... (195/199)
# Building sqlalchemy==2.0.41m 39.53 MiB/40.34 MiB
#    Built pypika==0.48.9
# Building sqlalchemy==2.0.41
#    Built pypika==0.48.9
# Building sqlalchemy==2.0.41
#    Built pypika==0.48.9
# Building sqlalchemy==2.0.41
#    Built pypika==0.48.9
# Building sqlalchemy==2.0.41
#    Built pypika==0.48.9
#    Built sqlalchemy==2.0.41
#    Built pypika==0.48.9
#    Built pypika==0.48.9
# Prepared 199 packages in 7.51s
# Installed 199 packages in 201ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.11.18
#  + aiosignal==1.3.2
#  + alembic==1.15.2
#  + annotated-types==0.7.0
#  + anyio==4.9.0
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==3.0.0
#  + attrs==25.3.0
#  + auth0-python==4.9.0
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + beautifulsoup4==4.13.4
#  + blinker==1.9.0
#  + build==1.2.2.post1
#  + cachetools==5.5.2
#  + certifi==2025.4.26
#  + cffi==1.17.1
#  + charset-normalizer==3.4.2
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.2.0
#  + cohere==5.15.0
#  + coloredlogs==15.0.1
#  + crewai==0.119.0
#  + crewai-tools==0.44.0
#  + cryptography==44.0.3
#  + dataclasses-json==0.6.7
#  + decorator==5.2.1
#  + deprecated==1.2.18
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + durationpy==0.9
#  + embedchain==0.1.128
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.115.12
#  + fastavro==1.10.0
#  + filelock==3.18.0
#  + flatbuffers==25.2.10
#  + frozenlist==1.6.0
#  + fsspec==2025.3.2
#  + google-auth==2.40.1
#  + googleapis-common-protos==1.70.0
#  + gptcache==0.1.44
#  + greenlet==3.2.2
#  + grpcio==1.71.0
#  + h11==0.16.0
#  + h2==4.2.0
#  + hpack==4.1.0
#  + httpcore==1.0.9
#  + httptools==0.6.4
#  + httpx==0.28.1
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.31.2
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + importlib-metadata==8.6.1
#  + importlib-resources==6.5.2
#  + instructor==1.8.1
#  + ipython==8.36.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.8.2
#  + json-repair==0.44.1
#  + json5==0.12.0
#  + jsonpatch==1.33
#  + jsonpickle==4.0.5
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2025.4.1
#  + kubernetes==32.0.1
#  + lancedb==0.22.0
#  + langchain==0.3.25
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.24
#  + langchain-core==0.3.59
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.8
#  + langsmith==0.3.42
#  + litellm==1.68.0
#  + mako==1.3.10
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.98
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.4.3
#  + mypy-extensions==1.1.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==2.2.5
#  + oauthlib==3.2.2
#  + onnxruntime==1.22.0
#  + openai==1.75.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.33.0
#  + opentelemetry-exporter-otlp-proto-common==1.33.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.33.0
#  + opentelemetry-exporter-otlp-proto-http==1.33.0
#  + opentelemetry-instrumentation==0.54b0
#  + opentelemetry-instrumentation-asgi==0.54b0
#  + opentelemetry-instrumentation-fastapi==0.54b0
#  + opentelemetry-proto==1.33.0
#  + opentelemetry-sdk==1.33.0
#  + opentelemetry-semantic-conventions==0.54b0
#  + opentelemetry-util-http==0.54b0
#  + orjson==3.10.18
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parso==0.8.4
#  + pdfminer-six==20250327
#  + pdfplumber==0.11.6
#  + pexpect==4.9.0
#  + pillow==11.2.1
#  + portalocker==2.10.1
#  + posthog==3.25.0
#  + prompt-toolkit==3.0.51
#  + propcache==0.3.1
#  + protobuf==5.29.4
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==20.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.22
#  + pydantic==2.11.4
#  + pydantic-core==2.33.2
#  + pydantic-settings==2.9.1
#  + pygments==2.19.1
#  + pyjwt==2.10.1
#  + pypdf==5.5.0
#  + pypdfium2==4.30.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.400
#  + pysbd==0.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.0
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.14.2
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.24.0
#  + rsa==4.9.1
#  + schema==0.7.7
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.7
#  + sqlalchemy==2.0.41
#  + stack-data==0.6.3
#  + starlette==0.46.2
#  + sympy==1.14.0
#  + tabulate==0.9.0
#  + tenacity==9.1.2
#  + tiktoken==0.9.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.15.3
#  + types-requests==2.32.0.20250328
#  + typing-extensions==4.13.2
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.0
#  + tzdata==2025.2
#  + urllib3==2.4.0
#  + uv==0.7.3
#  + uvicorn==0.34.2
#  + uvloop==0.21.0
#  + watchfiles==1.0.5
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0.1
#  + wrapt==1.17.2
#  + yarl==1.20.0
#  + zipp==3.21.0
#  + zstandard==0.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 1eabffb0-bfdd-42f0-91de-d5d839e39de6                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 19f0d3b1-72c3-4b89-b479-9f4ab4ecf538
#        Status: Executing Task...
#
# 🚀 Crew: crew
# └── 📋 Task: 19f0d3b1-72c3-4b89-b479-9f4ab4ecf538
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: In Progress
#
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
# 🤖 Agent: AI LLMs Senior Data Researcher
#
#     Status: In Progress
# └── 🧠 Thinking...
#
# 🤖 Agent: AI LLMs Senior Data Researcher
#
#     Status: In Progress
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **Model Scaling Trends**: As of 2024, there is a pronounced trend toward scaling large language models (LLMs), with companies pushing the boundaries of number parameters, leading to improved performance and comprehension capabilities. Models like OpenAI's GPT-4 have reached billions of parameters, enhancing their ability to understand context and generate coherent texts.
#
# 2. **Efficiency Improvements**: Researchers have developed better methods for training large models with less computational resources, utilizing techniques such as quantization and sparsity, which have made it more feasible for smaller companies and academic institutions to work with advanced LLMs.
#
# 3. **Hybrid Approaches**: In 2024, hybrid models combining rule-based systems with LLMs are gaining traction. These models are designed to leverage the strengths of deterministic AI alongside the probabilistic nature of LLMs, resulting in higher accuracy and better contextual understanding, especially in specialized fields.
#
# 4. **Ethical AI Development**: There is a heightened focus on the ethical implications of LLMs, with initiatives launched to ensure responsible AI development. Frameworks and guidelines are being established to mitigate biases and ensure fairness in model outputs, addressing criticism from various stakeholders.
#
# 5. **Multimodal Models**: Continued advancements in multimodal AI are notable in 2024, with models capable of processing text, image, and audio inputs simultaneously. OpenAI's developments in this area have enabled richer interactions and more comprehensive understanding of complex queries.
#
# 6. **Personalization in AI**: LLMs are increasingly being fine-tuned for individual users, enabling personalized responses based on historical interactions and user preferences. This shift toward user-centric AI is expected to enhance user experience significantly across multiple applications.
#
# 7. **Real-Time Applications**: The implementation of LLMs in real-time applications, such as chatbots and virtual assistants, has significantly improved. Businesses in sectors like healthcare and customer service are utilizing LLMs for instant and accurate responses, thereby increasing operational efficiency.
#
# 8. **Open-Source Contributions**: The open-source movement has gained momentum, with organizations like EleutherAI and Hugging Face providing access to advanced models and tools. This collaboration accelerates research and innovation, allowing wider accessibility to cutting-edge LLM technologies.
#
# 9. **Regulatory Developments**: As AI technologies evolve, so too do the regulatory frameworks surrounding them. Governments worldwide are drafting policies directed at AI accountability, impacting how LLMs are developed and deployed, with an emphasis on data privacy and security.
#
# 10. **Integrative Learning Environments**: Companies and educational institutions are increasingly adopting integrative learning environments that incorporate LLMs to enhance learning experiences. By personalizing educational content and offering interactive discussions, LLMs are transforming traditional education methodologies.
#
#
# 🚀 Crew: crew
# └── 📋 Task: 19f0d3b1-72c3-4b89-b479-9f4ab4ecf538
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# └── 📋 Task: 19f0d3b1-72c3-4b89-b479-9f4ab4ecf538
#        Assigned to: AI LLMs Senior Data Researcher
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 19f0d3b1-72c3-4b89-b479-9f4ab4ecf538                                  │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 19f0d3b1-72c3-4b89-b479-9f4ab4ecf538
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 0b82a01b-03a4-4a45-aa2a-6126091539bd
#        Status: Executing Task...
#
# 🚀 Crew: crew
# ├── 📋 Task: 19f0d3b1-72c3-4b89-b479-9f4ab4ecf538
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 0b82a01b-03a4-4a45-aa2a-6126091539bd
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: In Progress
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Comprehensive Report on the Current State of Large Language Models (LLMs) in 2024
#
# ## 1. Model Scaling Trends
# As of 2024, the significant trend in the AI landscape involves the scaling of large language models (LLMs). Companies are aggressively expanding model sizes, pushing the limits of parameters to billions. Notably, models such as OpenAI's GPT-4 have exemplified this trend, showcasing a remarkable improvement in performance and comprehension capabilities. The sheer increase in the number of parameters contributes to a deeper understanding of context, allowing for more coherent and contextually relevant text generation. This scalability not only enhances the models' capacities to perform natural language processing tasks but also affects various applications, from conversational agents to automated content generation. As organizations prioritize model scaling, they also face challenges like increased computational requirements and potential environmental impacts, prompting a dual focus on performance and sustainability.
#
# ## 2. Efficiency Improvements
# Against the backdrop of large-scale LLMs, researchers are introducing innovative methods to improve efficiency in model training. Techniques such as quantization, which reduces the precision of the numbers used in computations, and sparsity, which involves training models with a proportion of parameters set to zero, are instrumental in reducing resource consumption. These efficiency gains are pivotal for smaller companies and academia, allowing them to access advanced LLM technologies that were once only feasible for tech giants with vast computing resources. The adoption of these methodologies not only lowers the barrier to entry for various entities but also invites a broader participation in AI research and development, cultivating a more diverse ecosystem of LLM applications.
#
# ## 3. Hybrid Approaches
# In 2024, hybrid approaches that merge rule-based systems with LLMs are becoming increasingly prominent. These integrated models combine the deterministic strengths of traditional AI systems with the statistical advantages of LLMs. The synergy between the two methodologies enhances model accuracy and contextual comprehension, proving especially effective in specialized domains such as healthcare, legal, and technical fields. For example, a hybrid model could utilize rule-based logic to ensure compliance with regulatory standards while benefiting from LLM capabilities for dynamic language processing. This approach caters to applications requiring high fidelity and interpretability, potentially improving user trust and satisfaction.
#
# ## 4. Ethical AI Development
# The evolution of ethical AI development is gathering momentum as stakeholders emphasize the social implications of deploying LLMs. A growing number of initiatives focus on establishing robust frameworks and guidelines aimed at combating biases within AI outputs and safeguarding fairness. As criticism regarding AI biases escalates, organizations are instituting comprehensive training practices to generate equitable and reliable models. This ethical lens is not only critical for compliance with emerging regulations but also for fostering public trust in AI technologies. Stakeholders from diverse backgrounds—including developers, ethicists, and end-users—are engaging in collaborative dialogues to shape these standards, ensuring that AI serves as a tool for positive societal impact.
#
# ## 5. Multimodal Models
# The continued advancement in multimodal AI capabilities in 2024 reflects a significant progression towards integrating various forms of data inputs. Models are now being developed that can simultaneously process text, images, and audio, enhancing the richness of interactions and the complexity of understanding in AI applications. OpenAI's innovations in this domain allow for more fluid and natural communication between users and AI systems, enabling comprehensive responses that encompass multiple modalities. The implications of multimodal models are profound, permitting applications in fields ranging from virtual reality to advanced customer support systems that can dynamically adjust responses based on the mode of input received, thus enriching user experiences.
#
# ## 6. Personalization in AI
# Personalization is becoming a cornerstone of LLM applications. In 2024, advancements in fine-tuning techniques enable LLMs to provide tailored responses based on individual user histories and preferences. This shift towards user-centric AI results in significantly enhanced experiences across various applications, from e-commerce recommendations to personalized learning environments. By leveraging user data effectively, LLMs can adapt to specific needs, fostering more engaging and relevant interactions. The focus on personalization promises to redefine customer relationships and educational methodologies, allowing individuals to receive content and solutions ideally suited to their unique contexts.
#
# ## 7. Real-Time Applications
# The deployment of LLMs in real-time applications has witnessed significant advancements, especially in sectors such as healthcare and customer service. In 2024, businesses are leveraging LLM technologies to enable chatbots and virtual assistants to deliver prompt and accurate responses, greatly enhancing operational efficiency. These applications automate routine inquiries and processes, freeing human resources for more complex tasks. The ability to provide instant feedback in customer interactions not only improves satisfaction rates but also contributes to reduced waiting times, ultimately driving better service outcomes. Industries are recognizing the competitive advantages of integrating LLMs in real-time environments, leading to widespread adoption and innovation.
#
# ## 8. Open-Source Contributions
# The open-source movement surrounding AI is gaining notable momentum, with several organizations, including EleutherAI and Hugging Face, leading the charge in democratizing access to advanced LLMs and supporting tools. This collaborative effort fosters transparency and inclusivity in AI research, enabling a wider audience to engage with and build upon existing technologies. The implications of open-source contributions are profound, as they expedite innovation and encourage diverse applications from various sectors. By lowering the barrier for entry, more researchers and developers can participate in the rapidly evolving landscape of AI, facilitating the discovery of novel applications and techniques.
#
# ## 9. Regulatory Developments
# As AI technologies evolve, so do the regulatory frameworks that govern them. As of 2024, global governments are proactively drafting policies aimed at enhancing accountability within the AI ecosystem. These regulations focus on critical areas such as data privacy, security, and the ethical deployment of AI technologies like LLMs. The increased scrutiny fosters a landscape where accountability is paramount, necessitating organizations to implement robust compliance measures. The interplay between rapid technological advancement and regulatory adaptation presents both challenges and opportunities for AI developers. Navigating these developments will be essential for ensuring that LLMs are leveraged responsibly.
#
# ## 10. Integrative Learning Environments
# In 2024, integrative learning environments powered by LLMs are reshaping traditional education methodologies. Companies and educational institutions increasingly incorporate these advanced technologies to deliver personalized educational contexts. By tailoring content to suit individual learning paces and allowing for interactive discussions, LLMs enhance educational experiences, fostering engagement and deeper understanding. The potential for real-time feedback and adaptative learning paths represents a revolutionary shift in how educational content is delivered, paving the way for lifelong learning opportunities. This trend signifies a growing acceptance of AI as a legitimate partner in education, pushing boundaries in how knowledge is imparted and absorbed.
#
# In conclusion, the landscape of large language models in 2024 represents a dynamic convergence of technological advancements, ethical considerations, and emergent regulatory frameworks. Stakeholders across industries are recognizing the transformative potential of LLMs, striving to leverage these capabilities responsibly and inclusively. As further innovations unfold, the collaborative efforts within the AI community promise to reshape the future of intelligent systems.
#
#
# 🚀 Crew: crew
# ├── 📋 Task: 19f0d3b1-72c3-4b89-b479-9f4ab4ecf538
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 0b82a01b-03a4-4a45-aa2a-6126091539bd
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# ├── 📋 Task: 19f0d3b1-72c3-4b89-b479-9f4ab4ecf538
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 0b82a01b-03a4-4a45-aa2a-6126091539bd
#        Assigned to: AI LLMs Reporting Analyst
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 0b82a01b-03a4-4a45-aa2a-6126091539bd                                  │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 1eabffb0-bfdd-42f0-91de-d5d839e39de6                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
